# %%
import cv2, matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('downloads/noguchi02.jpg')
print(image)
# Out:
# [[[ 72  99 143]
#   [ 76 103 147]
#   [ 78 106 147]
#   ...,
#   [159 186 207]
#   [160 187 213]
#   [157 187 212]]
#
#  [[ 74 101 145]
#   [ 77 104 148]
#   [ 77 105 146]
#   ...,
#   [160 187 208]
#   [158 186 210]
#   [153 183 208]]
#
#  [[ 76 103 147]
#   [ 77 104 148]
#   [ 76 104 145]
#   ...,
#   [157 181 203]
#   [160 188 212]
#   [158 186 210]]
#
#  ...,
#  [[ 39  78 130]
#   [ 39  78 130]
#   [ 40  79 131]
#   ...,
#   [193 210 223]
#   [195 212 225]
#   [197 214 227]]
#
#  [[ 32  71 123]
#   [ 32  71 123]
#   [ 32  71 123]
#   ...,
#   [198 215 228]
#   [200 217 230]
#   [200 217 230]]
#
#  [[ 39  78 130]
#   [ 39  78 130]
#   [ 39  78 130]
#   ...,
#   [199 216 229]
#   [200 217 230]
#   [201 218 231]]]

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
plt.show()

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.imshow(gray_image)
plt.show()

# %%
print(gray_image)
# Out:
# [[109 113 115 ..., 189 192 191]
#  [111 114 114 ..., 190 190 187]
#  [113 114 113 ..., 185 192 190]
#  ...,
#  [ 89  89  90 ..., 212 214 216]
#  [ 82  82  82 ..., 217 219 219]
#  [ 89  89  89 ..., 218 219 220]]

# %%
plt.imshow(image)
plt.show()

# %%
average_color_per_row = np.average(image, axis=0)
average_color = np.average(average_color_per_row, axis=0)
average_color = np.uint8(average_color)
print(average_color)
# Out:
# [179 146 123]

# %%
print(average_color_per_row)
# Out:
# [[ 158.49666667  120.18666667   95.29666667]
#  [ 158.475       120.18166667   95.28833333]
#  [ 158.40333333  120.23833333   95.395     ]
#  ...,
#  [ 235.40833333  228.76        218.39666667]
#  [ 235.91        229.265       218.92666667]
#  [ 236.12        229.48833333  219.18666667]]

# %%
print(np.average(average_color_per_row, axis=0))
# Out:
# [ 179.91531458  146.44999167  123.05688333]

# %%
average_color_image = np.array([[average_color]*100]*100, np.uint8)
plt.imshow(average_color_image)

# %%
plt.show()

# %%
threshold_image = cv2.threshold(gray_image, 60, 255, cv2.THRESH_BINARY)

# %%
plt.imshow(threshold_image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-05e9d63b1a58> in <module>()
# ----> 1 plt.imshow(threshold_image)
#       2 plt.show()
#
# /home/aswin/project/random_stuff/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3078                         filternorm=filternorm, filterrad=filterrad,
#    3079                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3080                         **kwargs)
#    3081     finally:
#    3082         ax._hold = washold
#
# /home/aswin/project/random_stuff/local/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
# ...

# %%
gray_image

# %%
_, threshold_image = cv2.threshold(gray_image, 60, 255, cv2.THRESH_BINARY)
threshold_image = cv2.cvtColor(threshold_image, cv2.COLOR_GRAY2RGB)
plt.imshow(threshold_image)

# %%
plt.show()

# %%
plt.show()

# %%
plt.show()

# %%
import cv2, matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('downloads/noguchi02.jpg')

# %%
image
# Out:
# array([[[ 72,  99, 143],
#         [ 76, 103, 147],
#         [ 78, 106, 147],
#         ...,
#         [159, 186, 207],
#         [160, 187, 213],
#         [157, 187, 212]],
#
#        [[ 74, 101, 145],
#         [ 77, 104, 148],
#         [ 77, 105, 146],
#         ...,
#         [160, 187, 208],
#         [158, 186, 210],
#         [153, 183, 208]],
#
#        [[ 76, 103, 147],
#         [ 77, 104, 148],
#         [ 76, 104, 145],
#         ...,
#         [157, 181, 203],
#         [160, 188, 212],
#         [158, 186, 210]],
#
#        ...,
#        [[ 39,  78, 130],
#         [ 39,  78, 130],
#         [ 40,  79, 131],
#         ...,
#         [193, 210, 223],
#         [195, 212, 225],
#         [197, 214, 227]],
#
#        [[ 32,  71, 123],
#         [ 32,  71, 123],
#         [ 32,  71, 123],
#         ...,
#         [198, 215, 228],
#         [200, 217, 230],
#         [200, 217, 230]],
#
#        [[ 39,  78, 130],
#         [ 39,  78, 130],
#         [ 39,  78, 130],
# ...

# %%
plt.imshow(image)
plt.show()

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.show()

# %%
image_rgb
# Out:
# array([[[143,  99,  72],
#         [147, 103,  76],
#         [147, 106,  78],
#         ...,
#         [207, 186, 159],
#         [213, 187, 160],
#         [212, 187, 157]],
#
#        [[145, 101,  74],
#         [148, 104,  77],
#         [146, 105,  77],
#         ...,
#         [208, 187, 160],
#         [210, 186, 158],
#         [208, 183, 153]],
#
#        [[147, 103,  76],
#         [148, 104,  77],
#         [145, 104,  76],
#         ...,
#         [203, 181, 157],
#         [212, 188, 160],
#         [210, 186, 158]],
#
#        ...,
#        [[130,  78,  39],
#         [130,  78,  39],
#         [131,  79,  40],
#         ...,
#         [223, 210, 193],
#         [225, 212, 195],
#         [227, 214, 197]],
#
#        [[123,  71,  32],
#         [123,  71,  32],
#         [123,  71,  32],
#         ...,
#         [228, 215, 198],
#         [230, 217, 200],
#         [230, 217, 200]],
#
#        [[130,  78,  39],
#         [130,  78,  39],
#         [130,  78,  39],
# ...

# %%
plt.show()

# %%
plt.imshow(image)
plt.show()

# %%
plt.imshow(image_rgb)
plt.show()

# %%
average_row_color = np.average(image_rgb, axis=0)

# %%
average_row_color
# Out:
# array([[ 158.49666667,  120.18666667,   95.29666667],
#        [ 158.475     ,  120.18166667,   95.28833333],
#        [ 158.40333333,  120.23833333,   95.395     ],
#        ...,
#        [ 235.40833333,  228.76      ,  218.39666667],
#        [ 235.91      ,  229.265     ,  218.92666667],
#        [ 236.12      ,  229.48833333,  219.18666667]])

# %%
average_image_color = np.average(average_row_color, axis=0)
average_image_color
# Out:
# array([ 179.91531458,  146.44999167,  123.05688333])

# %%
average_color_image = np.array([[average_color]*100]*100, np.uint8)

# %%
average_color_image
# Out:
# array([[[179, 146, 123],
#         [179, 146, 123],
#         [179, 146, 123],
#         ...,
#         [179, 146, 123],
#         [179, 146, 123],
#         [179, 146, 123]],
#
#        [[179, 146, 123],
#         [179, 146, 123],
#         [179, 146, 123],
#         ...,
#         [179, 146, 123],
#         [179, 146, 123],
#         [179, 146, 123]],
#
#        [[179, 146, 123],
#         [179, 146, 123],
#         [179, 146, 123],
#         ...,
#         [179, 146, 123],
#         [179, 146, 123],
#         [179, 146, 123]],
#
#        ...,
#        [[179, 146, 123],
#         [179, 146, 123],
#         [179, 146, 123],
#         ...,
#         [179, 146, 123],
#         [179, 146, 123],
#         [179, 146, 123]],
#
#        [[179, 146, 123],
#         [179, 146, 123],
#         [179, 146, 123],
#         ...,
#         [179, 146, 123],
#         [179, 146, 123],
#         [179, 146, 123]],
#
#        [[179, 146, 123],
#         [179, 146, 123],
#         [179, 146, 123],
# ...

# %%
plt.imshow(average_color_image)
plt.show()

# %%
grayscale_image = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(grayscale_image)
plt.show()

# %%
coins_bgr = cv2.imread("downloads/coins.jpg")

# %%
coins_rgb = cv2.cvtColor(coins_bgr, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(coins_rgb)
plt.show()

# %%
coins_gray = coins_rgb
plt.imshow(coins_gray)
plt.show()

# %%
ret, thresh1 = cv2.threshold(coins_gray, 127, 255, cv2.THRESH_BINARY)

# %%
thresh1
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
plt.imshow(thresh1)
plt.show()

# %%
ret, thresh2 = cv2.threshold(coins_gray, 127, 255, cv2.THRESH_TOZERO_INV)
plt.imshow(thresh2)
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
image = cv2.imread('downloads/coins.jpg')
plt.imshow(image)

# %%
plt.show()

# %%
ret, threshold_1 = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)

# %%
threshold_1
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(threshold_1)
plt.show()

# %%
ret, threshold_2 = cv2.threshold(image, 127, 255, cv2.THRESH_TRUNC)
plt.imshow(threshold_2)
plt.show()

# %%
ret, threshold = cv2.threshold(image, 127, 255, cv2.THRESH_BIN_INV)
plt.imshow(threshold)
plt.show()
